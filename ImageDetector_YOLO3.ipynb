# %%
"""
YOLOを利用した物体検出を行う
"""
# %cd /content/drive/My Drive/Colab Notebooks/ImageScripts/yolov3-tf2
# Out:
# /content/drive/My Drive/Colab Notebooks/ImageScripts/yolov3-tf2

# %%
# YOLOの重みファイルをtensorflowように変換
# !python convert.py --weights ./data/yolov3.weights --output ./checkpoints/yolov3.tf
# Out:
# 2020-10-26 03:44:56.097075: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-26 03:44:57.472986: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-26 03:44:57.524289: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-26 03:44:57.524869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-26 03:44:57.524918: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# 物体検出 (出力先: ./output.jpg)
# !python detect.py --image ./data/office.jpg
# Out:
# 2020-10-26 03:45:07.883811: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-26 03:45:09.245313: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-26 03:45:09.280972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-26 03:45:09.281551: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-10-26 03:45:09.281601: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
import IPython
IPython.display.Image('/content/drive/My Drive/Colab Notebooks/ImageScripts/yolov3-tf2/output.jpg')
